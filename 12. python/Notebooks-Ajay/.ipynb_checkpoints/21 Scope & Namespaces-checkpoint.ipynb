# %% [markdown]
# # Scope

# %%
dog = "Ugly street dog"

def home():
    dog = "My sweet pet"
    return dog

bark = home()

# %% [markdown]
# ## locals and globals

# %%
bark

# %%
dog

# %% [markdown]
# ## System globals

# %%
dog_has_tail = True

# %% [markdown]
# ## globals

# %%
CAR_COLOR = "Blue"

def try_to_change_me():
    CAR_COLOR = "White"
    return CAR_COLOR

changed_color = try_to_change_me()
changed_color
# Out:
# 'White'

# %%
CAR_COLOR

# %%
def try_to_change_me():
    global CAR_COLOR
    CAR_COLOR = "White"
    return CAR_COLOR

changed_color = try_to_change_me()
changed_color
CAR
# Out:
# 'White'

# %%
CAR_COLOR
# Out:
# 'White'

# %% [markdown]
# # Namespaces

# %% [markdown]
# - Think of namespaces as a note which keeps list of all the names that are availabe in a scope.
# - Namespaces bascially tells interpreter about what is accessible and what is not.
# - All the names that are available to use in a score will be part of the namespace for that scope.
# - Namespaces are the reason you can have same function name in python in two different class or module, you can run them together and they will never get conflicted (Because they have seperate namespaces.)

# %%
import pprint # just for a beautiful output

pprint.pprint(locals())  # locals of outer scope. Although same as globals technically
# Out:
# {'CAR_COLOR': 'White',
#  'In': ['',
#         'CAR_COLOR = "Blue"\n'
#         '\n'
#         'def try_to_change_me():\n'
#         '    CAR_COLOR = "White"\n'
#         '    return CAR_COLOR\n'
#         '\n'
#         'changed_color = try_to_change_me()\n'
#         'changed_color',
#         'def try_to_change_me():\n'
#         '    global CAR_COLOR\n'
#         '    CAR_COLOR = "White"\n'
#         '    return CAR_COLOR\n'
#         '\n'
#         'changed_color = try_to_change_me()\n'
#         'changed_color',
#         'CAR_COLOR',
#         'def try_to_change_me():\n'
#         '    CAR_COLOR = "White"\n'
#         '    pprint.pprint(locals())\n'
#         '\n'
#         'try_to_change_me()',
#         'import pprint # just for a beautiful output\n'
#         '\n'
#         'pprint.pprint(locals())  # locals of outer scope. Although same as '
#         'globals technically'],
#  'Out': {1: 'White', 2: 'White', 3: 'White'},
#  '_': 'White',
#  '_1': 'White',
#  '_2': 'White',
#  '_3': 'White',
#  '__': 'White',
#  '___': 'White',
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__session__': '/home/root483/Desktop/Notebooks/21 Scope & Namespaces.ipynb',
#  '__spec__': None,
#  '_dh': [PosixPath('/home/root483/Desktop/Notebooks')],
#  '_i': 'def try_to_change_me():\n'
#        '    CAR_COLOR = "White"\n'
#        '    pprint.pprint(locals())\n'
#        '\n'
#        'try_to_change_me()',
#  '_i1': 'CAR_COLOR = "Blue"\n'
#         '\n'
#         'def try_to_change_me():\n'
#         '    CAR_COLOR = "White"\n'
#         '    return CAR_COLOR\n'
#         '\n'
#         'changed_color = try_to_change_me()\n'
#         'changed_color',
#  '_i2': 'def try_to_change_me():\n'
#         '    global CAR_COLOR\n'
#         '    CAR_COLOR = "White"\n'
#         '    return CAR_COLOR\n'
#         '\n'
#         'changed_color = try_to_change_me()\n'
#         'changed_color',
#  '_i3': 'CAR_COLOR',
#  '_i4': 'def try_to_change_me():\n'
#         '    CAR_COLOR = "White"\n'
#         '    pprint.pprint(locals())\n'
#         '\n'
#         'try_to_change_me()',
#  '_i5': 'import pprint # just for a beautiful output\n'
#         '\n'
#         'pprint.pprint(locals())  # locals of outer scope. Although same as '
#         'globals technically',
#  '_ih': ['',
#          'CAR_COLOR = "Blue"\n'
#          '\n'
#          'def try_to_change_me():\n'
#          '    CAR_COLOR = "White"\n'
#          '    return CAR_COLOR\n'
#          '\n'
#          'changed_color = try_to_change_me()\n'
#          'changed_color',
#          'def try_to_change_me():\n'
#          '    global CAR_COLOR\n'
#          '    CAR_COLOR = "White"\n'
#          '    return CAR_COLOR\n'
#          '\n'
#          'changed_color = try_to_change_me()\n'
#          'changed_color',
#          'CAR_COLOR',
#          'def try_to_change_me():\n'
#          '    CAR_COLOR = "White"\n'
#          '    pprint.pprint(locals())\n'
#          '\n'
#          'try_to_change_me()',
#          'import pprint # just for a beautiful output\n'
#          '\n'
#          'pprint.pprint(locals())  # locals of outer scope. Although same as '
#          'globals technically'],
#  '_ii': 'CAR_COLOR',
#  '_iii': 'def try_to_change_me():\n'
#          '    global CAR_COLOR\n'
#          '    CAR_COLOR = "White"\n'
#          '    return CAR_COLOR\n'
#          '\n'
#          'changed_color = try_to_change_me()\n'
#          'changed_color',
#  '_oh': {1: 'White', 2: 'White', 3: 'White'},
#  'changed_color': 'White',
#  'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x7cf3101b0100>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7cf3101733a0>>,
#  'open': <function open at 0x7cf31215aef0>,
#  'pprint': <module 'pprint' from '/usr/lib/python3.10/pprint.py'>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x7cf3101b0100>,
#  'try_to_change_me': <function try_to_change_me at 0x7cf3101bd900>}

# %%
def try_to_change_me():
    CAR_COLOR = "White"
    pprint.pprint(locals())

try_to_change_me()
# Out:
# {'CAR_COLOR': 'White'}

# %% [markdown]
# # Making it fun! nonlocal

# %%
x = "a"
def outer():
    x = "b"
    def inner():
        x = "c"
        print("from inner:", x)

    inner()
    print("from outer:", x)

outer()
print("globally:", x)
# Out:
# from inner: c
# from outer: b
# globally: a

# %%
x = "a"
def outer():
    x = "b"
    def inner():
        nonlocal x
        x = "c"
        print("inner:", x)

    inner()
    print("outer:", x)

outer()
print("global:", x)
# Out:
# inner: c
# outer: c
# global: a

# %%
x = "a"
def outer():
    x = "b"
    def inner():
        global x
        x = "c"
        print("inner:", x)

    inner()
    print("outer:", x)

outer()
print("global:", x)
# Out:
# inner: c
# outer: b
# global: c

# %% [markdown]
# # The LEGB rule

# %% [markdown]
# - As you saw before, namespaces can exist independently from eachother, and have certain levels of hierarchy, which we refer to as their scope. Depending on where you are in a program, a different namespace will be used. To determine in which order Python should access namespaces, you can use the LEGB rule.
#
# - LEGB stands for:
#     - local
#     - Enclosed
#     - Global
#     - Built-in

# %% [markdown]
# - Let's say you're calling print(x) within inner(), which is a function nested in outer(). Then Python will first look if x was defined locally in that inner(). If not, the variable defined in outer() will be used. This is the enclosing function. If it also wasn't defined there, the Python interpreter will go up another level, to the global scope. Above that you will only find the built-in scope, which contains special variables reserverd for Python itself.

# %%
x = 0

def outer():
    # Enclosed scope
    x = 1
    def inner():
        # Local scope
        x = 2
